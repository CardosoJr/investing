# %%
import aiohttp
import pandas as pd 
import xml.etree.ElementTree as ET
from datetime import datetime
import re

# %%
texto = "oii remover <dentro o parentes> asdads"

# %%
re.sub(r'\<[^)]*\>', '', texto)
# Out:
# 'oii remover  asdads'

# %%
url = "https://www.infomoney.com.br/feed/"
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:87.0) Gecko/20100101 Firefox/87.0'
}

# %%
session = aiohttp.ClientSession()

# %%
response = await session.get(url, headers=headers, timeout=60)

# %%
text = await response.text()
root = ET.fromstring(text)

# %%
channel = root.find('channel/item/title').text
channel
# Out:
# 'Verde Asset: texto da reforma tributária merece nota zero com louvor'

# %%
pubDate = root.find('channel/item/pubDate').text
pubDate
# Out:
# 'Sun, 11 Jul 2021 14:05:28 +0000'

# %%
published = datetime.strptime(pubDate.replace("GMT", "+0000"), '%a, %d %b %Y %H:%M:%S %z')
published
# Out:
# datetime.datetime(2021, 7, 11, 14, 5, 28, tzinfo=datetime.timezone.utc)

# %%
title = channel.encode('UTF-8').decode('UTF-8')
title
# Out:
# 'Verde Asset: texto da reforma tributária merece nota zero com louvor'

# %%
df = pd.DataFrame([])
clean = re.compile('<.*?>')
data = []
for item in root.findall('channel/item'):
    article = {}
    article['title'] = item.find('title').text.encode('UTF-8').decode('UTF-8')
    article['pub_date'] = datetime.strptime(item.find('pubDate').text.replace("GMT", "+0000"), '%a, %d %b %Y %H:%M:%S %z')
    article['description'] = re.sub(clean, '', item.find('description').text).replace('\n', " ")
    data.append(pd.DataFrame(article, index = [0]))

df = pd.concat(data, ignore_index = True)

# %%
df
# Out:
#                                                title  \
# 0  Verde Asset: texto da reforma tributária merec...
# 1  PIB da China, resultados e inflação nos EUA, I...
# 2  Totvs quer ir além dos sistemas de gestão para...
# 3  Gustavo Constantino, da Távola Capital, conta ...
# 4  Gestora global responsável por US$ 730 bi reco...
# 5  MPF busca acordo definitivo com Samarco e quer...
# 6  Burger King anuncia acordo para assumir operaç...
# 7  TSE diz que atuação para impedir eleições conf...
# 8  Eleições fazem parte da democracia e Congresso...
# 9  Guedes: IR sobre dividendos está entre 20% e 4...
#
#                    pub_date                                        description
# 0 2021-07-11 14:05:28+00:00  Daniel Leichsenring, economista-chefe da Vede ...
# 1 2021-07-11 12:00:48+00:00  Tudo que o investidor precisa saber antes de o...
# 2 2021-07-11 11:30:08+00:00  Totvs foi eleita a melhor empresa do setor de ...
# ...

# %%
url = "https://economia.uol.com.br/mais/ultimas-noticias/2021/06/25/acao-itausa-hoje-cotacao-ibovespa.htm"

# %%
response = await session.get(url, headers=headers, timeout=60)

# %%
text = await response.text()

# %%
re.sub(clean, "", text)
# Out:
# '      Ações Itaúsa (ITSA4): saiba qual o preço hoje                                                                                                                        /* !color-cp:back-to-top */.back-to-top{bottom:8px;position:fixed;right:8px;z-index:121}.back-to-top .box{display:block;background:rgba(26,26,26,.8);border:none;color:#fff;font-size:16px;height:40px;line-height:14px;width:40px}.back-to-top .box i{font-size:16px;margin:0 12px}.back-to-top .box span{display:block;font-size:11px;font-weight:400;text-align:center}@media (max-width:767px){.back-to-top .box i{display:inline-block}}.back-to-top .box{padding:6px 0 0}.back-to-top[data-show=false]{visibility:hidden}@media (min-width:992px){.back-to-top .box{background:#1a1a1a;height:50px;line-height:17px;padding-top:6px;transition:.5s;width:50px}.back-to-top .box i{font-size:20px;margin:0 15px}.back-to-top .box span{font-size:14px;line-height:19px}.back-to-top .box:hover{background-color:rgba(26,26,26,.8);color:#fff}}/* !end
# ...
